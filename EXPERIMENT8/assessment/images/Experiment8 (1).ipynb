# %%
import cv2
import numpy as np

# %%
img = cv2.imread('/content/ipcv image.jpeg')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
h, s, v = cv2.split(hsv)

# %%
lower_h = 35
upper_h = 85
#yellow image
lower_h = 20
upper_h = 35
#for blue image
lower_h = 90
upper_h = 130
#for purple
lower_h = 130
upper_h = 160

# %%
# mask = cv2.inRange(h, lower_h, upper_h)
#for blue
mask = cv2.inRange(h, lower_h, upper_h)
result = cv2.bitwise_and(img, img, mask=mask)
#for purple
mask = cv2.inRange(h, lower_h, upper_h)
result = cv2.bitwise_and(img, img, mask=mask)

# %%
# for yellow
result = cv2.bitwise_and(img, img, mask=mask)
result = cv2.bitwise_and(img, img, mask=mask)
cv2.imwrite("purplepic.jpg", result)
# Out:
# True

# %%
cv2.imwrite("greenpic.jpg", result)
cv2.imwrite("bluepic.jpg", result)
# Out:
# True

# %%
cv2.imwrite("yellowpic.jpg", result)
# Out:
# True

# %%
cv2.imwrite("whiteimage.jpg", mask)
# Out:
# True
